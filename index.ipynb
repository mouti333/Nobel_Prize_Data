# %% [markdown]
# ![img](./image/nobel-prize.jpg)
# ## Les Prix Nobel  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <p>Le prix Nobel est peut-être le prix scientifique le plus connu au monde. Sauf pour l’honneur, le prestige, et l’argent substantiel de prix le récipiendaire obtient également une médaille d’or montrant Alfred Nobel (1833 - 1896) qui a établi le prix. Chaque année, il est remis à des scientifiques et à des universitaires dans les catégories de la chimie, de la littérature, de la physique, de la physiologie ou de la médecine, de l’économie et de la paix. </p>
# <p>La Fondation Nobel a mis à disposition un ensemble de données de tous les lauréats depuis le début du prix, en 1901, jusqu’en 2016. Chargeons-le et jetons un œil.</p>
#
# -------
#
# ## Les étapes:
# 1. Les prix Nobel
# 2. Alors, qui reçoit le prix Nobel ?
# 3. Domination des États-Unis
# 4. La domination des États-Unis, visualisée
# 5. Quel est le sexe d'un lauréat typique du prix Nobel ?
# 6. Les premières femmes et hommes à remporter le Prix Nobel.
# 7. Répéter les lauréats
# 8. Lauréats du prix Nobel par âge
# 9. Différences d'âge entre les catégories de prix
# 10. Gagnants les plus âgés et les plus jeunes
# 11. Nom du plus jeune gagnant !

# %% [markdown]
# ## 1️⃣ Les prix Nobel
# ##### ✏️Importer les `bibliothèques requises`
# ##### ✏️Lire l'ensemble de données à partir de `data/nobel.csv`
# ##### ✏️Afficher les `six premières` entrées de nobel

# %%
#Chargement dans les bibliothèques requises
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#Lecture des données du prix Nobel
nobel = pd.read_csv("./Data/nobel.csv")

# %%
#Les 6 premiers lauréats
nobel.head(n=6)
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
# 5  1901     Physics                 The Nobel Prize in Physics 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
# ...

# %%
#La méthode info() imprime des informations sur le DataFrame . 
# #Les informations contiennent le nombre de colonnes, les étiquettes de colonne, les types de données de colonne, l'utilisation de la mémoire, l'index de plage et le nombre de cellules dans chaque colonne (valeurs non nulles).
nobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 911 entries, 0 to 910
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  911 non-null    int64
#  1   category              911 non-null    object
#  2   prize                 911 non-null    object
#  3   motivation            823 non-null    object
#  4   prize_share           911 non-null    object
#  5   laureate_id           911 non-null    int64
#  6   laureate_type         911 non-null    object
#  7   full_name             911 non-null    object
#  8   birth_date            883 non-null    object
#  9   birth_city            883 non-null    object
#  10  birth_country         885 non-null    object
#  11  sex                   885 non-null    object
#  12  organization_name     665 non-null    object
#  13  organization_city     667 non-null    object
#  14  organization_country  667 non-null    object
# ...

# %%
#La méthode renvoie la description des données dans le DataFrame.
# utilisé pour afficher certains détails statistiques de base comme le centile, la moyenne, la norme, etc
nobel.describe()
# Out:
#               year  laureate_id
# count   911.000000   911.000000
# mean   1969.201976   462.515917
# std      32.837978   270.236159
# min    1901.000000     1.000000
# 25%    1946.000000   228.500000
# 50%    1975.000000   457.000000
# 75%    1997.000000   698.500000
# max    2016.000000   937.000000

# %%
#Renvoie les n dernières lignes.
nobel.tail()
# Out:
#      year  category                                           prize  \
# 906  2016  Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016     Peace                      The Nobel Peace Prize 2016
# 908  2016   Physics                 The Nobel Prize in Physics 2016
# 909  2016   Physics                 The Nobel Prize in Physics 2016
# 910  2016   Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# 906  "for his discoveries of mechanisms for autophagy"         1/1
# 907  "for his resolute efforts to bring the country...         1/1
# 908  "for theoretical discoveries of topological ph...         1/2
# 909  "for theoretical discoveries of topological ph...         1/4
# 910  "for theoretical discoveries of topological ph...         1/4
#
#      laureate_id laureate_type              full_name  birth_date birth_city  \
# ...

# %% [markdown]
# ## 2️⃣ Alors, qui reçoit le prix Nobel ?
# ##### ✏️Comptez le nombre de rangs/prix. Utilisez la `display()`fonction pour afficher le résultat
# ##### ✏️Comptez et affichez le nombre de prix pour chaque sexe en utilisant la `value_counts()` méthode.
# ##### ✏️Comptez le nombre de prix pour chaque `birth_country` utilisation `value_counts()`et affichez le top 10. N'utilisez pas display()

# %%
# Afficher le nombre de Prix Nobel remis (éventuellement partagés)
#Nbre entre 1901 et 2016
display(len(nobel))
# Out:
# 911

# %%
# Afficher le nombre de prix remportés par les lauréats masculins et féminins.
display(nobel['sex'].value_counts())
# Out:
# Male      836
# Female     49
# Name: sex, dtype: int64

# %%
# Afficher le nombre de prix remportés par les 10 premières nationalités.
nobel['birth_country'].value_counts().head(10)
# Out:
# United States of America    259
# United Kingdom               85
# Germany                      61
# France                       51
# Sweden                       29
# Japan                        24
# Canada                       18
# Netherlands                  18
# Italy                        17
# Russia                       17
# Name: birth_country, dtype: int64

# %% [markdown]
# ## 3️⃣ Domination des États-Unis
# ### le lauréat le plus commun entre 1901 et 2016 était un homme né aux États-Unis d’Amérique. Mais en 1901, tous les lauréats étaient européens. Quand les Etats-Unis ont-ils commencé à dominer les palmarès du prix Nobel ?
# ### Créez un DataFrame avec deux colonnes : `decade and proportion de lauréats du prix Nobel` nés aux États-Unis cette décennie.
# ##### ✏️Ajoutez une colonne `usa_born_winner` à `Nobel`, où la `valeur est True` lorsque `birth_country` est `"United States of America"`.
# ##### ✏️Ajoutez `une colonne de dix ans` à `Nobel` pour la décennie où chaque prix a été décerné. Ici, `np.floor()` sera utile. Assurez-vous que la colonne de la décennie est de `type int64`.
# ##### ✏️Utilisez `groupby` pour grouper par décennie, en définissant `as_index=False`. Puis isolez la colonne `usa_born_winner` et prenez `la moyenne()`.  Attribuez le DataFrame résultant à `prop_usa_winners`.
# ##### ✏️Afficher `prop_usa_winners`.

# %%
# Calcul de la proportion de gagnants nés aux États-Unis par décennie
nobel['usa_born_winner'] = nobel['birth_country'] == "United States of America"
# Calculer la décennie
nobel['decade'] = (np.floor(nobel["year"] / 10) * 10).astype(int)
# Calculer la moyenne par décennie
prop_usa_winners = nobel.groupby("decade",as_index=False)["usa_born_winner"].mean()

# Afficher les proportions de gagnants nés aux États-Unis par décennie
prop_usa_winners
# Out:
#     decade  usa_born_winner
# 0     1900         0.017544
# 1     1910         0.075000
# 2     1920         0.074074
# 3     1930         0.250000
# 4     1940         0.302326
# 5     1950         0.291667
# 6     1960         0.265823
# 7     1970         0.317308
# 8     1980         0.319588
# 9     1990         0.403846
# 10    2000         0.422764
# 11    2010         0.292683

# %% [markdown]
# #### Voici le moyenne de prix Nobel par pays maintenant que nous voulons connaître la décennie avec plus de prix Nobel pour les États-Unis.

# %%
# Extraire la plus grande valeur
prop_usa_winners.nlargest(1, 'usa_born_winner')
# Out:
#     decade  usa_born_winner
# 10    2000         0.422764

# %%
# Extraire la plus petite valeur
prop_usa_winners.nsmallest(1, 'usa_born_winner')
# Out:
#    decade  usa_born_winner
# 0    1900         0.017544

# %% [markdown]
# ## 4️⃣ La domination des États-Unis, visualisée
# ### Pour voir quand les USA ont commencé à dominer les charts Nobel il faut une `plot`
# ##### ✏️Utiliser `seaborn to plot` pour tracer le `prop_usa_winners` avec `decade` sur l’axe des x et `usa_born_winner` sur l’axe des y comme un `sns.lineplot`. Assigner `plot` à `ax`
# ##### ✏️Fixer l’échelle Y de sorte que le est affiche les pourcentages en utilisant `PercentFormatter`

# %%
# Définition du thème de tracé
sns.set()
# et la taille de tous les tracés.
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [11, 7]
#Nbre de gagnants nés aux États-Unis 
ax = sns.lineplot(x='decade', y='usa_born_winner', data=prop_usa_winners)
# Ajout du formatage %à l’axe des y
from matplotlib.ticker import PercentFormatter
ax.yaxis.set_major_formatter(PercentFormatter(1.0))

# %% [markdown]
# ## 5️⃣ Quel est le sexe d'un lauréat typique du prix Nobel ?
# #### Ainsi, les États-Unis sont devenus le gagnant dominant du prix Nobel d’abord dans les années 1930 et avait gardé la position de leader depuis. Mais un groupe qui était en tête depuis le début, et qui ne semble jamais lâcher prise, ce sont les hommes. Cela ne devrait peut-être pas être un choc qu’il y ait un certain déséquilibre entre le nombre de lauréats masculins et féminins, mais quelle est l’importance de ce déséquilibre? Et est-il meilleur ou pire dans certaines catégories de prix comme la physique, la médecine, la littérature, etc.?
# #### Répartition de la proportion de femmes lauréates par décennie par catégorie de prix.
# ##### ✏️Ajoutez la colonne `female_winner` à `Nobel`, où la valeur est True lorsque `le sexe est "Female"`.
# ##### ✏️Utilisez `groupby` pour regrouper par décennie et par catégorie, en définissant `as_index=False`. Puis isolez la colonne `female_winner` et prenez `la moyenne()`. Attribuez le DataFrame résultant à `prop_female_winners`.
# ##### ✏️Copiez et collez votre graphe de `seaborn plot ` de la tâche 4 (y compris le code de formatage d’axe), mais tracez prop_female_winners et mappez la variable de catégorie au paramètre de teinte.

# %%
#Calcul de la proportion de femmes lauréates par décennie
nobel['female_winner'] = nobel['sex']  == 'Female'
prop_female_winners = nobel.groupby(['decade', 'category'], as_index=False)['female_winner'].mean()

#Nombre de femmes gagnantes 
ax = sns.lineplot(x='decade', y='female_winner', data=prop_female_winners, hue='category')

# Ajout du formatage %à l’axe des y
ax.yaxis.set_major_formatter(PercentFormatter())

# %%
#Calcul de la proportion de femmes lauréates par décennienobel['female_winner'] = nobel['sex'] == 'Female'
prop_female_winners = nobel.groupby(['decade', 'category'], as_index=False)['female_winner'].mean()

#Nombre de femmes gagnantes 
ax = sns.barplot(x="decade", y="female_winner", hue="category", data=prop_female_winners)

#Ajout d’étiquettes d’axes, de titre et de légende
plt.title("The proportion of female winners per decade by categories", 
          fontdict={'fontsize': 14},
          fontweight ='bold',
          loc='center')
plt.ylabel("Female winners ratio")
plt.xlabel("Decade")
plt.legend(loc='upper left')

# Ajout du formatage %à l’axe des y
from matplotlib.ticker import PercentFormatter
ax.yaxis.set_major_formatter(PercentFormatter())

# %% [markdown]
# #### Répartition de la proportion de hommes lauréates par décennie par catégorie de prix.
# ##### ✏️Ajoutez la colonne `male_winner` à `Nobel`, où la valeur est True lorsque `le sexe est "male"`.
# ##### ✏️Utilisez `groupby` pour regrouper par décennie et par catégorie, en définissant `as_index=False`. Puis isolez la colonne `male_winner` et prenez `la moyenne()`. Attribuez le DataFrame résultant à `prop_male_winners`.
# ##### ✏️Copiez et collez votre graphe de `seaborn plot ` de la tâche 4 (y compris le code de formatage d’axe), mais tracez prop_male_winners et mappez la variable de catégorie au paramètre de teinte.

# %%
#Calcul de la proportion de femmes lauréates par décennie
nobel['male_winner'] = nobel['sex']  == 'Male'
prop_male_winners = nobel.groupby(['decade', 'category'], as_index=False)['male_winner'].mean()

#Nombre de femmes gagnantes 
ax = sns.lineplot(x='decade', y='male_winner', data=prop_male_winners, hue='category')

# Ajout du formatage %à l’axe des y
ax.yaxis.set_major_formatter(PercentFormatter())

# %%
#Calcul de la proportion de femmes lauréates par décennienobel['male_winner'] = nobel['sex'] == 'Male'
nobel['male_winner'] = nobel['sex'] == 'Male'
prop_male_winners = nobel.groupby(['decade', 'category'], as_index=False)['male_winner'].mean()

# Nombre de hommes gagnantes 
ax = sns.barplot(x="decade", y="male_winner", hue="category", data=prop_male_winners)

#Ajout d’étiquettes d’axes, de titre et de légende
plt.title("The proportion of male winners per decade by categories", 
          fontdict={'fontsize': 14},
          fontweight ='bold',
          loc='center')
plt.ylabel("male winners ratio")
plt.xlabel("Decade")
plt.legend(loc='upper left')

# Ajout du formatage %à l’axe des y
from matplotlib.ticker import PercentFormatter
ax.yaxis.set_major_formatter(PercentFormatter())

# %% [markdown]
# ## 6️⃣ Les premières femmes et hommes à remporter le Prix Nobel.
# #### Aqui a été le premier homme et femme à recevoir un prix Nobel? Et dans quelle catégorie?
# #### Répartition de la proportion de femmes lauréates par décennie par catégorie de prix.
# #### Extraire et afficher la rangée montrant la première femme à gagner un prix Nobel.
# ##### ✏️Sélectionnez seulement les rangées de `'Femmes'` gagnantes du prix Nobel.
# ##### ✏️En utilisant la méthode `nsmallest()` avec ses paramètres ` n` et colonnes, choisissez la première femme et le première homme à obtenir un prix Nobel.

# %%
# Choisir la première femme à remporter un prix Nobel
nobel[nobel['sex'] == 'Female'].nsmallest(n=1, columns='year')
# Out:
#     year category                            prize  \
# 19  1903  Physics  The Nobel Prize in Physics 1903
#
#                                            motivation prize_share  \
# 19  "in recognition of the extraordinary services ...         1/4
#
#     laureate_id laureate_type                    full_name  birth_date  \
# 19            6    Individual  Marie Curie, née Sklodowska  1867-11-07
#
#    birth_city  ... organization_name organization_city organization_country  \
# 19     Warsaw  ...               NaN               NaN                  NaN
#
#     death_date  death_city death_country usa_born_winner decade  \
# 19  1934-07-04  Sallanches        France           False   1900
#
#     female_winner  male_winner
# 19           True        False
#
# [1 rows x 22 columns]

# %%
# Choisir le première homme à remporter un prix Nobel
nobel[nobel['sex'] == 'Male'].nsmallest(n=1, columns='year')
# Out:
#    year   category                              prize  \
# 0  1901  Chemistry  The Nobel Prize in Chemistry 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
#
#   laureate_type                     full_name  birth_date birth_city  ...  \
# 0    Individual  Jacobus Henricus van 't Hoff  1852-08-30  Rotterdam  ...
#
#    organization_name organization_city organization_country  death_date  \
# 0  Berlin University            Berlin              Germany  1911-03-01
#
#   death_city death_country usa_born_winner decade  female_winner  male_winner
# 0     Berlin       Germany           False   1900          False         True
#
# [1 rows x 22 columns]

# %% [markdown]
# ## 7️⃣ Répéter les lauréats
# #### Pour la plupart des scientifiques/écrivains/activistes, un prix Nobel serait le couronnement d’une longue carrière. Mais pour certaines personnes, on est juste pas assez, et peu ont obtenu plus d’une fois. Qui sont ces quelques chanceux?
# #### Extraire et afficher les rangées de récipiendaires du prix Nobel.
# ##### ✏️Utilisez `groupby` pour grouper nobel par `'full_name'`.
# ##### ✏️Utilisez la méthode de `filter ` pour garder seulement les lignes dans `nobel` avec les gagnants avec 2 prix ou plus.

# %%
# Sélection des lauréats ayant reçu 2 prix ou plus.
nobel.groupby('full_name').filter(lambda x: len(x) >= 2)
# Out:
#      year   category                              prize  \
# 19   1903    Physics    The Nobel Prize in Physics 1903
# 62   1911  Chemistry  The Nobel Prize in Chemistry 1911
# 89   1917      Peace         The Nobel Peace Prize 1917
# 215  1944      Peace         The Nobel Peace Prize 1944
# 278  1954  Chemistry  The Nobel Prize in Chemistry 1954
# 283  1954      Peace         The Nobel Peace Prize 1954
# 298  1956    Physics    The Nobel Prize in Physics 1956
# 306  1958  Chemistry  The Nobel Prize in Chemistry 1958
# 340  1962      Peace         The Nobel Peace Prize 1962
# 348  1963      Peace         The Nobel Peace Prize 1963
# 424  1972    Physics    The Nobel Prize in Physics 1972
# 505  1980  Chemistry  The Nobel Prize in Chemistry 1980
# 523  1981      Peace         The Nobel Peace Prize 1981
#
#                                             motivation prize_share  \
# 19   "in recognition of the extraordinary services ...         1/4
# ...

# %% [markdown]
# ## 8️⃣ Lauréats du prix Nobel par âge
# #### En général, quel âge avaient les gagnants?
# #### Calculer et tracer l’âge de chaque gagnant quand ils ont gagné leur prix Nobel.
# ##### ✏️Convertir la colonne `nobel['birth_date']` en `datetime` en utilisant `pd.to_datetime`.
# ##### ✏️Ajouter une nouvelle colonne `nobel['age']` qui contient l’âge de chaque gagnant quand ils ont obtenu le prix `C’est année de gain moins année de naissance`.
# ##### ✏️Utiliser `sns.lmplot` (pas sns.lineplot) pour faire un graphe avec l’année sur l’axe des x et l’âge sur l’axe des y.

# %%
#pip install statsmodels

# %%
#Conversion date de naissance de chaîne en date time
nobel['birth_date'] = pd.to_datetime(nobel['birth_date'])

# Calcul de l’âge des lauréats du prix Nobel
nobel['age'] = nobel["year"] - nobel['birth_date'].dt.year

# Tracer l’âge des lauréats du prix Nobel
sns.lmplot(x='year',y='age',data=nobel,lowess=True,aspect=2,line_kws={'color': 'black'})

# %% [markdown]
# ## 9️⃣ Différences d'âge entre les catégories de prix
# #### Examinons les tendances de l’âge dans différentes catégories de prix.
# #### Indiquez l’âge des gagnants dans les différentes catégories de prix.
# ##### ✏️Comme précédemment, utiliser `sns.lmplot` pour faire un graphe avec l’année sur l’axe des x et l’âge sur l’axe des y. Mais cette fois, faites une intrigue par `category ` de prix en définissant l’argument de ligne à `'category '`.
# ##### Il s’agit du même graphique que dans la tâche 8, sauf avec `row= argument`

# %%
# Même intrigue que ci-dessus, mais parcelles séparées pour chaque type de prix Nobel
sns.lmplot(x="year", y="age", data=nobel, lowess=True, aspect=2,line_kws={'color' : 'black'}, row='category')

# %% [markdown]
# ## 🔟 Gagnants les plus âgés et les plus jeunes
# #### Nous voyons que les deux gagnants du prix de chimie, de médecine et de physique ont vieilli au fil du temps. La tendance est la plus forte pour la physique : l’âge moyen était inférieur à 50 ans, et maintenant il est presque 70. La littérature et l’économie sont plus stables. On voit aussi que l’économie est une nouvelle catégorie. Mais la paix montre une tendance inverse où les gagnants rajeunissent! Dans la catégorie paix, nous avons également un gagnant vers 2010 qui semble exceptionnellement jeune. Cela nous amène à nous demander qui sont les personnes les plus âgées et les plus jeunes à avoir remporté un prix Nobel?
# #### Choisissez les rangées du plus ancien et du plus jeune lauréat d’un prix Nobel.
# ##### ✏️Utilisez `nlargest()` pour sélectionner et afficher la rangée du plus ancien gagnant.
# ##### ✏️Utilisez `nsmallest()` pour choisir et afficher la rangée du plus jeune gagnant.
# ##### Comme précédemment, vous devrez utiliser `display()` pour afficher plus que la dernière sortie de la cellule.

# %%
# Le plus ancien lauréat d’un prix Nobel en 2016
display(nobel.nlargest(n=1, columns='age'))

# Le plus jeune lauréat d’un prix Nobel en 2016
nobel.nsmallest(n=1, columns='age')
# Out:
#      year   category                                              prize  \
# 793  2007  Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             motivation prize_share  \
# 793  "for having laid the foundations of mechanism ...         1/3
#
#      laureate_id laureate_type       full_name birth_date birth_city  ...  \
# 793          820    Individual  Leonid Hurwicz 1917-08-21     Moscow  ...
#
#     organization_city      organization_country  death_date       death_city  \
# 793   Minneapolis, MN  United States of America  2008-06-24  Minneapolis, MN
#
#                 death_country usa_born_winner decade female_winner  \
# 793  United States of America           False   2000         False
#
#      male_winner   age
# 793         True  90.0
#
# [1 rows x 23 columns]
#      year category                       prize  \
# 885  2014    Peace  The Nobel Peace Prize 2014
#
# ...

# %% [markdown]
# ## 1️⃣1️⃣  Nom du plus jeune gagnant !
# #### Quel était le nom de la plus jeune gagnante de l’histoire qui, en 2014, a reçu le prix pour sa lutte contre la répression des enfants et des jeunes et pour le droit de tous les enfants à l’éducation?
# ##### ✏️Attribuez le nom du plus jeune lauréat d’un prix Nobel à `youngest_winner`.

# %%
# Le nom du plus jeune lauréat du prix Nobel en 2016
youngest_winner = nobel.nsmallest(n=1, columns='age')['full_name'].iloc[0]
youngest_winner
# Out:
# 'Malala Yousafzai'
